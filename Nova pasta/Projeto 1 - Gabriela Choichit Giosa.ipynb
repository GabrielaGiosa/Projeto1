# %% [markdown]
# # Projeto 1 - Ciência dos Dados
# BRUTO

# %% [markdown]
# **Gabriela Choichit Giosa**
#
# **Engenharia 2°Semestre**
#
# **2019.2**

# %% [markdown]
# ## Pergunta a ser respondida:
#     Países da União Europeia tem um crescimento do indice de desenvolvimento humano mais acelerado que países de fora dela?

# %% [markdown]
# ## Explicação da hipótese e mecanismo:
#     1. Países da União Europeia estão menos propensos a sofrer abalos com a instabilidade do mercado internacional visto que há uma aliança economica entre eles que assegura comércio interno.
#     Com o apoio e investimentos de outros países da organização, eles tem maior chance de se desenvolver.
#     2. Já o mecanismo será a análise dos valores de renda dos países da União Europeia, em específico a renda da Polonia com o decorrer do tempo em paralelo com a renda da Ucrania, que é um paí que não pertence à organização e recentemente (em 1991) deixou de fazer parte da União Soviética.

# %% [markdown]
# ## Base de dados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\gabig_000\Documents\INSPER\2ºSEMESTRE\Ciência dos Dados\Projeto1

# %% [markdown]
# ## Renda anual de todos os países do mundo

# %%
dados = pd.read_excel('GDP_per_Capita1.xlsx')

# %%
dados
# Out:
#                     Countries    1800    1801    1802    1803    1804    1805  \
# 0                    Abkhazia     NaN     NaN     NaN     NaN     NaN     NaN
# 1                 Afghanistan   603.0   603.0   603.0   603.0   603.0   603.0
# 2       Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN
# 3                     Albania   667.0   667.0   668.0   668.0   668.0   668.0
# 4                     Algeria   716.0   716.0   717.0   718.0   719.0   720.0
# 5              American Samoa     NaN     NaN     NaN     NaN     NaN     NaN
# 6                     Andorra  1197.0  1199.0  1201.0  1204.0  1206.0  1208.0
# 7                      Angola   618.0   620.0   623.0   626.0   628.0   631.0
# 8                    Anguilla     NaN     NaN     NaN     NaN     NaN     NaN
# 9         Antigua and Barbuda   757.0   757.0   757.0   757.0   757.0   757.0
# 10                  Argentina  1507.0  1508.0  1508.0  1508.0  1508.0  1508.0
# ...

# %% [markdown]
# ## Dados usados para a análise - a partir de 1975

# %%
dados_1980 = dados.loc[:,['Countries', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015
]]

# %%
dados_1980
# Out:
#                     Countries      1980      1981      1982      1983  \
# 0                    Abkhazia       NaN       NaN       NaN       NaN
# 1                 Afghanistan    1158.0    1284.0    1402.0    1454.0
# 2       Akrotiri and Dhekelia       NaN       NaN       NaN       NaN
# 3                     Albania    4218.0    4227.0    4237.0    4248.0
# 4                     Algeria   10166.0   10160.0   10477.0   10696.0
# 5              American Samoa       NaN       NaN       NaN       NaN
# 6                     Andorra   32055.0   30795.0   29907.0   29143.0
# 7                      Angola    4443.0    4110.0    3970.0    3996.0
# 8                    Anguilla       NaN       NaN       NaN       NaN
# 9         Antigua and Barbuda    8169.0    8689.0    8827.0    9540.0
# 10                  Argentina   10982.0   10221.0    9765.0   10030.0
# 11                    Armenia    3815.0    3783.0    3809.0    3862.0
# ...

# %% [markdown]
# ## Tabela usada para separar países da União Europeia dos outros

# %%
Dados_regiao= pd.read_excel('WorldBank.xlsx')

# %%
Dados_regiao
# Out:
#                     Country  Population     GDPcapita  surface  \
# 0                   Albania     2901883   1915.424459    28750
# 1                   Algeria    36036159   2231.980246  2381740
# 2                    Angola    21219954    623.245275  1246700
# 3       Antigua and Barbuda       87233  10614.794315      440
# 4                 Argentina    41222875  10749.319224  2780400
# 5                   Armenia     2963496   1326.710864    29740
# 6                 Australia    22162863  25190.839860  7741220
# 7                   Austria     8391986  26642.993858    83870
# 8                Azerbaijan     9099893   2344.810935    86600
# 9                   Bahamas      360830  19395.152312    13880
# 10                  Bahrain     1261319  11236.404979      760
# 11               Bangladesh   151616777    558.062385   144000
# 12                  Belarus     9492122   2739.950643   207600
# 13                  Belgium    10929978  24550.396553    30530
# ...

# %%
Paises = Dados_regiao.loc[:, ["Country", "region", "GDPcapita"]]

# %%
Paises
# Out:
#                     Country              region     GDPcapita
# 0                   Albania         europe_east   1915.424459
# 1                   Algeria        africa_north   2231.980246
# 2                    Angola  africa_sub_saharan    623.245275
# 3       Antigua and Barbuda       america_north  10614.794315
# 4                 Argentina       america_south  10749.319224
# 5                   Armenia         europe_east   1326.710864
# 6                 Australia   east_asia_pacific  25190.839860
# 7                   Austria         europe_west  26642.993858
# 8                Azerbaijan         europe_east   2344.810935
# 9                   Bahamas       america_north  19395.152312
# 10                  Bahrain           asia_west  11236.404979
# 11               Bangladesh           asia_west    558.062385
# 12                  Belarus         europe_east   2739.950643
# 13                  Belgium         europe_west  24550.396553
# ...

# %%
Região = Dados_regiao.loc[:, ["region"]]

# %%
Dados_completos = Região.join(dados_1980, how='inner')
Dados_completos
# Out:
#                  region               Countries     1980     1981     1982  \
# 0           europe_east                Abkhazia      NaN      NaN      NaN
# 1          africa_north             Afghanistan   1158.0   1284.0   1402.0
# 2    africa_sub_saharan   Akrotiri and Dhekelia      NaN      NaN      NaN
# 3         america_north                 Albania   4218.0   4227.0   4237.0
# 4         america_south                 Algeria  10166.0  10160.0  10477.0
# 5           europe_east          American Samoa      NaN      NaN      NaN
# 6     east_asia_pacific                 Andorra  32055.0  30795.0  29907.0
# 7           europe_west                  Angola   4443.0   4110.0   3970.0
# 8           europe_east                Anguilla      NaN      NaN      NaN
# 9         america_north     Antigua and Barbuda   8169.0   8689.0   8827.0
# 10            asia_west               Argentina  10982.0  10221.0   9765.0
# ...

# %% [markdown]
# ## Juntando as tabelas para distinguir países que são da União Europeia

# %%
Uniao_europeia = Dados_completos[Dados_completos.region=='europe_west']

# %%
Uniao_europeia
# Out:
#           region                 Countries      1980     1981     1982  \
# 7    europe_west                    Angola    4443.0   4110.0   3970.0
# 13   europe_west                 Australia   23872.0  24308.0  23884.0
# 40   europe_west  Central African Republic    1103.0   1088.0   1077.0
# 41   europe_west                      Chad     891.0    880.0    884.0
# 52   europe_west                Costa Rica    7537.0   7190.0   6508.0
# 56   europe_west                    Cyprus   14582.0  14858.0  15638.0
# 58   europe_west            Czechoslovakia       NaN      NaN      NaN
# 68   europe_west                   Eritrea     942.0    943.0    925.0
# 72   europe_west            Faeroe Islands       NaN      NaN      NaN
# 74   europe_west                      Fiji    5843.0   6066.0   5560.0
# 86   europe_west                 Greenland   17449.0  17429.0  16479.0
# 93   europe_west             Guinea-Bissau    1500.0   1730.0   1790.0
# ...

# %% [markdown]
# ## Dados de desenvolvimento humano

# %%
IDH = pd.read_excel('Indicator_HDI.xlsx')

# %%
IDH
# Out:
#                            HDI   1980   1990   2000   2005   2006   2007  \
# 0                     Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN
# 1                  Afghanistan  0.198  0.246  0.230  0.340  0.354  0.363
# 2        Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN
# 3                      Albania    NaN  0.656  0.691  0.721  0.724  0.729
# 4                      Algeria  0.454  0.551  0.624  0.667  0.673  0.680
# 5               American Samoa    NaN    NaN    NaN    NaN    NaN    NaN
# 6                      Andorra    NaN    NaN    NaN    NaN    NaN    NaN
# 7                       Angola    NaN    NaN  0.384  0.445  0.459  0.471
# 8                     Anguilla    NaN    NaN    NaN    NaN    NaN    NaN
# 9          Antigua and Barbuda    NaN    NaN    NaN    NaN    NaN    NaN
# 10                   Argentina  0.669  0.697  0.749  0.765  0.773  0.780
# 11                     Armenia    NaN    NaN  0.643  0.689  0.703  0.715
# ...

# %%
D_IDH = IDH.loc[:, [1980,1990,2000,2005,2006,2007,2008,2009,2011]]

# %%
D_IDH
# Out:
#       1980   1990   2000   2005   2006   2007   2008   2009   2011
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    0.198  0.246  0.230  0.340  0.354  0.363  0.370  0.387  0.398
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN  0.656  0.691  0.721  0.724  0.729  0.733  0.734  0.739
# 4    0.454  0.551  0.624  0.667  0.673  0.680  0.686  0.691  0.698
# 5      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  0.838
# 7      NaN    NaN  0.384  0.445  0.459  0.471  0.476  0.481  0.486
# 8      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  0.764
# 10   0.669  0.697  0.749  0.765  0.773  0.780  0.786  0.788  0.797
# 11     NaN    NaN  0.643  0.689  0.703  0.715  0.719  0.712  0.716
# 12     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
Dados_IDH = Dados_completos.join(D_IDH, how='inner', lsuffix='_co2', rsuffix='_IDH')
Dados_IDH
# Out:
#                  region               Countries  1980_co2     1981     1982  \
# 0           europe_east                Abkhazia       NaN      NaN      NaN
# 1          africa_north             Afghanistan    1158.0   1284.0   1402.0
# 2    africa_sub_saharan   Akrotiri and Dhekelia       NaN      NaN      NaN
# 3         america_north                 Albania    4218.0   4227.0   4237.0
# 4         america_south                 Algeria   10166.0  10160.0  10477.0
# 5           europe_east          American Samoa       NaN      NaN      NaN
# 6     east_asia_pacific                 Andorra   32055.0  30795.0  29907.0
# 7           europe_west                  Angola    4443.0   4110.0   3970.0
# 8           europe_east                Anguilla       NaN      NaN      NaN
# 9         america_north     Antigua and Barbuda    8169.0   8689.0   8827.0
# 10            asia_west               Argentina   10982.0  10221.0   9765.0
# ...

# %%
dados_1980.set_index('Countries')
# Out:
#                               1980      1981      1982      1983      1984  \
# Countries
# Abkhazia                       NaN       NaN       NaN       NaN       NaN
# Afghanistan                 1158.0    1284.0    1402.0    1454.0    1429.0
# Akrotiri and Dhekelia          NaN       NaN       NaN       NaN       NaN
# Albania                     4218.0    4227.0    4237.0    4248.0    4259.0
# Algeria                    10166.0   10160.0   10477.0   10696.0   10947.0
# American Samoa                 NaN       NaN       NaN       NaN       NaN
# Andorra                    32055.0   30795.0   29907.0   29143.0   28394.0
# Angola                      4443.0    4110.0    3970.0    3996.0    4099.0
# Anguilla                       NaN       NaN       NaN       NaN       NaN
# Antigua and Barbuda         8169.0    8689.0    8827.0    9540.0   10388.0
# Argentina                  10982.0   10221.0    9765.0   10030.0   10102.0
# ...

# %%
UE = ['Countries' == 'Austria', 'Belgium', ' Bulgaria', ' Croatia', ' Republic of Cyprus', ' Czech Republic', ' Denmark', ' Estonia', ' Finland', ' France', ' Germany', ' Greece', ' Hungary', ' Ireland', ' Italy', ' Latvia', ' Lithuania', ' Luxembourg', ' Malta', ' Netherlands', ' Poland', ' Portugal', ' Romania', ' Slovakia', ' Slovenia', ' Spain', ' Sweden'
]
dados_1980.loc[UE]
# Out:
# C:\Users\gabig_000\OneDrive\Documentos\anaconda\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   This is separate from the ipykernel package so we can avoid doing imports until
#                     Countries  1980  1981  1982  1983  1984  1985  1986  1987  \
# False                Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Belgium                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#  Bulgaria                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#  Croatia                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#  Republic of Cyprus       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...
